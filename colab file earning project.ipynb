# %% [markdown]
# # Statistical Intuitions and Applications

# %% [markdown]
# ## Assignment - 1

# %% [markdown]
# Main Setup. For this assignment you will select a random sample from a dataset using the codes given below with all the detailed steps. To select your random sample and save your data set on your computer follow these instructions:
#
# Run the Sample size code below to find the sample size 'n' on which you will work.
# Go the 3rd line of CSV file code below and enter your sample size n = ???
# Now go the 4th line: df.to_csv(r'Path where you want to store the exported CSV file\FileName.csv')
# Change Path where you want to store the exported CSV file to where you want to store your data.
# Change File Name to your first name.
# Run the code.
# Once you run these two codes, your CSV file will be saved on your device at the same location you provided. Using the third code "Access the file ..." below, you will acces this file. Also include this CSV file in your assignment submission!
#
# Don't run the first two codes over and over again, once you have formally started working on your assignment.

# %%
# CSV File
import pandas as pd
original_data = pd.read_csv("earning_dataframe.csv")

# %%
original_data
# Out:
#      Academic_Year Institution_Type_EN Campus_Zone_EN LocalFlag_EN Gender_EN  \
# 0             2013             Federal      Abu Dhabi        Expat    Female
# 1             2013             Federal      Abu Dhabi        Expat      Male
# 2             2013             Federal      Abu Dhabi        Local    Female
# 3             2013             Federal      Abu Dhabi        Local      Male
# 4             2013             Federal          Dubai        Expat    Female
# ..             ...                 ...            ...          ...       ...
# 404           2021         Non-Federal        Sharjah        Local      Male
# 405           2021         Non-Federal  Umm Al-Quwain        Expat    Female
# 406           2021         Non-Federal  Umm Al-Quwain        Expat      Male
# 407           2021         Non-Federal  Umm Al-Quwain        Local    Female
# 408           2021         Non-Federal  Umm Al-Quwain        Local      Male
#
# ...
